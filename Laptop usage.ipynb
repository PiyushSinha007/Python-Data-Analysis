# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/Users/piyushsinha/Downloads/Dataset123.csv")

# %%
df.head()
# Out:
#    Age  Gender     EducationLevel  HouseholdIncome  Frequency_LaptopDesktop  \
# 0   25  Female  Bachelor's Degree        1500000.0                        4
# 1   48  Female  Bachelor's Degree         800000.0                        3
# 2   49    Male    Master's Degree       30000000.0                        4
# 3   38    Male  Bachelor's Degree          20000.0                        1
# 4   45    Male  Bachelor's Degree        5000000.0                        5
#
#    Frequency_Smartphone  Frequency_Tablet  Frequency_SmartHomeDevices  \
# 0                     5                 0                           4
# 1                     5                 5                           4
# 2                     4                 0                           2
# 3                     0                 1                           1
# 4                     5                 3                           5
#
#    Frequency_WearableDevices  Frequency_GamingConsoles  ...  \
# ...

# %%
df.tail()
# Out:
#      Age  Gender        EducationLevel  HouseholdIncome  \
# 102   38  Female       Master's Degree         400000.0
# 103   25    Male     Bachelor's Degree         840000.0
# 104   46    Male       Master's Degree       10000000.0
# 105   58  Female  High School Graduate       11200000.0
# 106   24  Female     Bachelor's Degree         456000.0
#
#      Frequency_LaptopDesktop  Frequency_Smartphone  Frequency_Tablet  \
# 102                        5                     5                 3
# 103                        4                     5                 3
# 104                        4                     5                 3
# 105                        5                     5                 0
# 106                        1                     5                 0
#
#      Frequency_SmartHomeDevices  Frequency_WearableDevices  \
# 102                           3                          4
# 103                           0                          2
# ...

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Age                                  0
# Gender                               0
# EducationLevel                       0
# HouseholdIncome                      0
# Frequency_LaptopDesktop              0
# Frequency_Smartphone                 0
# Frequency_Tablet                     0
# Frequency_SmartHomeDevices           0
# Frequency_WearableDevices            0
# Frequency_GamingConsoles             0
# Frequency_HomeSecuritySystem         0
# LikelinessToAdopt                    0
# Benefit_ProductivityEfficiency       0
# Benefit_CommunicationConnectivity    0
# Benefit_EasyAccessToInfo             0
# Benefit_Entertainment                0
# Risk_SecurityPrivacy                 0
# Risk_ExcessScreenTime                0
# Risk_ComplicatedToUse                0
# Risk_Addiction                       0
# Risk_Health                          0
# Risk_LossOfConnection                0
# Influence_FamilyFriends              0
# Influence_PromoActivities            0
# ...

# %%
df.head()
# Out:
#    Age  Gender     EducationLevel  HouseholdIncome  Frequency_LaptopDesktop  \
# 0   25  Female  Bachelor's Degree        1500000.0                        4
# 1   48  Female  Bachelor's Degree         800000.0                        3
# 2   49    Male    Master's Degree       30000000.0                        4
# 3   38    Male  Bachelor's Degree          20000.0                        1
# 4   45    Male  Bachelor's Degree        5000000.0                        5
#
#    Frequency_Smartphone  Frequency_Tablet  Frequency_SmartHomeDevices  \
# 0                     5                 0                           4
# 1                     5                 5                           4
# 2                     4                 0                           2
# 3                     0                 1                           1
# 4                     5                 3                           5
#
#    Frequency_WearableDevices  Frequency_GamingConsoles  ...  \
# ...

# %%
df.describe()
# Out:
#               Age  HouseholdIncome  Frequency_LaptopDesktop  \
# count  106.000000     1.060000e+02               106.000000
# mean    40.537736     3.088980e+06                 3.509434
# std     13.547922     6.938562e+06                 1.898597
# min     19.000000     1.500000e+04                 0.000000
# 25%     25.000000     5.000000e+05                 2.000000
# 50%     45.000000     9.000000e+05                 4.000000
# 75%     50.750000     2.000000e+06                 5.000000
# max     73.000000     5.000000e+07                 5.000000
#
#        Frequency_Smartphone  Frequency_Tablet  Frequency_SmartHomeDevices  \
# count            106.000000        106.000000                  106.000000
# mean               4.216981          1.952830                    2.896226
# std                1.573620          1.832937                    1.897011
# min                0.000000          0.000000                    0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106 entries, 0 to 106
# Data columns (total 33 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                106 non-null    int64
#  1   Gender                             106 non-null    object
#  2   EducationLevel                     106 non-null    object
#  3   HouseholdIncome                    106 non-null    float64
#  4   Frequency_LaptopDesktop            106 non-null    int64
#  5   Frequency_Smartphone               106 non-null    int64
#  6   Frequency_Tablet                   106 non-null    int64
#  7   Frequency_SmartHomeDevices         106 non-null    int64
#  8   Frequency_WearableDevices          106 non-null    int64
#  9   Frequency_GamingConsoles           106 non-null    int64
#  10  Frequency_HomeSecuritySystem       106 non-null    int64
# ...

# %%
df["Gender"].value_counts ()
# Out:
# Male      80
# Female    26
# Name: Gender, dtype: int64

# %%
sns.histplot(x = "Age", data =df, hue="Gender").set_title('Number of Male and Female by Age')
# Out:
# Text(0.5, 1.0, 'Number of Male and Female by Age')

# %%
plt.figure(figsize=(8, 4))
sns.histplot(x = "EducationLevel", data =df, hue="Gender").set_title('Education Level by Gender')
# Out:
# Text(0.5, 1.0, 'Education Level by Gender')

# %%
plt.bar(df["Frequency_LaptopDesktop"],df["Age"])
plt.xlabel ("Frequency_LaptopDesktop")
plt.ylabel("Age")
plt.title('Frequency of using Laptop/Desktop')
# Out:
# Text(0.5, 1.0, 'Frequency of using Laptop/Desktop')

# %%
plt.bar(df["Risk_SecurityPrivacy"],df["Age"])
plt.xlabel ("Risk_SecurityPrivacy")
plt.ylabel("Age")
plt.title('Risk to Security and Privacy by Age')
# Out:
# Text(0.5, 1.0, 'Risk to Security and Privacy by Age')

# %%
sns.histplot(x="Risk_Health",  y="Age", data =df, hue="Gender").set_title('Health Risk Factor Among Male and Female by Age')
# Out:
# Text(0.5, 1.0, 'Health Risk Factor Among Male and Female by Age')

# %%
sns.lineplot(x="Frequency_LaptopDesktop", y="Age", hue="Gender",palette=["m", "g"], data=df).set_title('Frecuency of Using Laptop/Desktop Among Males and Females by Age')
# Out:
# Text(0.5, 1.0, 'Frecuency of Using Laptop/Desktop Among Males and Females by Age')
